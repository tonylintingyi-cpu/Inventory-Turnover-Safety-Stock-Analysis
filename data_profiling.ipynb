# %% [markdown]
# # Import pandas and veltix_raw_data.csv

# %%
import pandas as pd
df = pd.read_csv('data/raw/veltix_raw_data.csv')
print(f"Loaded Dataset: {df.shape[0]} rows, {df.shape[1]} columns")
# Out:
# Loaded Dataset: 8034 rows, 10 columns

# %% [markdown]
# # Data Conceptualising

# %%
df
# Out:
#       sku_id      product_category   week_id  sales_qty  inventory_begin  \
# 0     SH-005            Smart Home  2023-W28       24.0            180.0
# 1     WR_007             Wearables  2024-W12       35.0            466.0
# 2     aU-010                 Audio  2024-W17       33.0           1776.0
# 3     WR-005             Wearables  2023-W52      180.0            492.0
# 4     MA-003    Mobile Accessories  2023-W07      166.0           1659.0
# ...      ...                   ...       ...        ...              ...
# 8029  CP-004  Computer Peripherals  2024-W27      115.0              NaN
# 8030  CP-005  Computer Peripherals  2024-W35       61.0            551.0
# 8031  MA-006    Mobile Accessories  2024-W29      133.0           1155.0
# 8032  SH-009            Smart Home  2025-W12        8.0            325.0
# 8033  SH-007            Smart Home  2024-W43        NaN            588.0
#
#       inventory_end  receipts  lead_time_days  unit_cost  holding_cost_rate
# 0               156         0               0      69.09               0.25
# 1               431         0               0      65.79               0.30
# 2              1743         0               0      57.05               0.28
# 3               312         0               0     131.41               0.30
# 4              1493         0               0       5.65               0.25
# ...             ...       ...             ...        ...                ...
# 8029            663         0               0      44.48               0.25
# 8030            490         0               0      25.49               0.25
# 8031           1022         0               0      19.49               0.25
# 8032            317         0               0      28.70               0.25
# 8033            532         0               0      36.19               0.25
#
# [8034 rows x 10 columns]

# %% [markdown]
# ## Data type

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8034 entries, 0 to 8033
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sku_id             8034 non-null   str
#  1   product_category   8034 non-null   str
#  2   week_id            8034 non-null   str
#  3   sales_qty          7759 non-null   float64
#  4   inventory_begin    7751 non-null   float64
#  5   inventory_end      8034 non-null   int64
#  6   receipts           8034 non-null   int64
#  7   lead_time_days     8034 non-null   int64
#  8   unit_cost          8034 non-null   float64
#  9   holding_cost_rate  8034 non-null   float64
# dtypes: float64(4), int64(3), str(3)
# memory usage: 627.8 KB
